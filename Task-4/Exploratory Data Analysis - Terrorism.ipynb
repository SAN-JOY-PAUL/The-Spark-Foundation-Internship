# %% [markdown]
# # **GRIP @ The Sparks Foundation**
# # **Author: Sanjoy Paul**
# ## **Domain: Data Science & Business Analytics**
# ## **Task-4: Exploratory Data Analysis-Terrorism**
# ### **Dataset: https://bit.ly/2TK5Xn5**

# %% [markdown]
# ### **Importing Libraries**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")
# %matplotlib inline

# %% [markdown]
# ### **Reading Dataset**

# %%
df=pd.read_csv('globalterrorismdb_0718dist.csv',encoding='latin1')
df.head()
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
# 2         Philippines       5  ...      NaN    NaN    NaN     NaN      PGIS
# 3              Greece       8  ...      NaN    NaN    NaN     NaN      PGIS
# 4               Japan       4  ...      NaN    NaN    NaN     NaN      PGIS
#
# ...

# %%
df.columns
# Out:
# Index(['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended',
#        'resolution', 'country', 'country_txt', 'region',
#        ...
#        'addnotes', 'scite1', 'scite2', 'scite3', 'dbsource', 'INT_LOG',
#        'INT_IDEO', 'INT_MISC', 'INT_ANY', 'related'],
#       dtype='object', length=135)

# %%
df.rename(columns={'iyear':'Year','imonth':'Month','iday':"day",'gname':'Group','country_txt':'Country','region_txt':'Region','provstate':'State','city':'City','latitude':'latitude',
    'longitude':'longitude','summary':'summary','attacktype1_txt':'Attacktype','targtype1_txt':'Targettype','weaptype1_txt':'Weapon','nkill':'kill',
     'nwound':'Wound'},inplace=True)

# %%
df = df[['Year','Month','day','Country','State','Region','City','latitude','longitude',"Attacktype",'kill',
               'Wound','target1','summary','Group','Targettype','Weapon','motive']]

# %%
df.head()
# Out:
#    Year  Month  day             Country    State                       Region  \
# 0  1970      7    2  Dominican Republic      NaN  Central America & Caribbean
# 1  1970      0    0              Mexico  Federal                North America
# 2  1970      1    0         Philippines   Tarlac               Southeast Asia
# 3  1970      1    0              Greece   Attica               Western Europe
# 4  1970      1    0               Japan  Fukouka                    East Asia
#
#             City   latitude   longitude                      Attacktype  kill  \
# 0  Santo Domingo  18.456792  -69.951164                   Assassination   1.0
# 1    Mexico city  19.371887  -99.086624     Hostage Taking (Kidnapping)   0.0
# 2        Unknown  15.478598  120.599741                   Assassination   1.0
# 3         Athens  37.997490   23.762728               Bombing/Explosion   NaN
# 4        Fukouka  33.580412  130.396361  Facility/Infrastructure Attack   NaN
#
# ...

# %%
df.tail()
# Out:
#         Year  Month  day      Country            State  \
# 181686  2017     12   31      Somalia  Middle Shebelle
# 181687  2017     12   31        Syria         Lattakia
# 181688  2017     12   31  Philippines      Maguindanao
# 181689  2017     12   31        India          Manipur
# 181690  2017     12   31  Philippines      Maguindanao
#
#                             Region           City   latitude   longitude  \
# 181686          Sub-Saharan Africa  Ceelka Geelow   2.359673   45.385034
# 181687  Middle East & North Africa         Jableh  35.407278   35.942679
# 181688              Southeast Asia       Kubentog   6.900742  124.437908
# 181689                  South Asia         Imphal  24.798346   93.940430
# 181690              Southeast Asia  Cotabato City   7.209594  124.241966
#
#                             Attacktype  kill  Wound           target1  \
# 181686                   Armed Assault   1.0    2.0        Checkpoint
# ...

# %%
df.shape
# Out:
# (181691, 18)

# %%
df.isnull().sum()
# Out:
# Year               0
# Month              0
# day                0
# Country            0
# State            421
# Region             0
# City             434
# latitude        4556
# longitude       4557
# Attacktype         0
# kill           10313
# Wound          16311
# target1          636
# summary        66129
# Group              0
# Targettype         0
# Weapon             0
# motive        131130
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Data columns (total 18 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   Year        181691 non-null  int64
#  1   Month       181691 non-null  int64
#  2   day         181691 non-null  int64
#  3   Country     181691 non-null  object
#  4   State       181270 non-null  object
#  5   Region      181691 non-null  object
#  6   City        181257 non-null  object
#  7   latitude    177135 non-null  float64
#  8   longitude   177134 non-null  float64
#  9   Attacktype  181691 non-null  object
#  10  kill        171378 non-null  float64
#  11  Wound       165380 non-null  float64
#  12  target1     181055 non-null  object
#  13  summary     115562 non-null  object
#  14  Group       181691 non-null  object
#  15  Targettype  181691 non-null  object
#  16  Weapon      181691 non-null  object
#  17  motive      50561 non-null   object
# ...

# %%
df.describe().T
# Out:
#               count         mean            std           min          25%  \
# Year       181691.0  2002.638997      13.259430  1.970000e+03  1991.000000
# Month      181691.0     6.467277       3.388303  0.000000e+00     4.000000
# day        181691.0    15.505644       8.814045  0.000000e+00     8.000000
# latitude   177135.0    23.498343      18.569242 -5.315461e+01    11.510046
# longitude  177134.0  -458.695653  204778.988611 -8.618590e+07     4.545640
# kill       171378.0     2.403272      11.545741  0.000000e+00     0.000000
# Wound      165380.0     3.167668      35.949392  0.000000e+00     0.000000
#
#                    50%          75%          max
# Year       2009.000000  2014.000000  2017.000000
# Month         6.000000     9.000000    12.000000
# day          15.000000    23.000000    31.000000
# latitude     31.467463    34.685087    74.633553
# longitude    43.246506    68.710327   179.366667
# kill          0.000000     2.000000  1570.000000
# ...

# %%
df['Year'].unique()
# Out:
# array([1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980,
#        1981, 1986, 1982, 1983, 1984, 1985, 1987, 1988, 1989, 1990, 1991,
#        1992, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003,
#        2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014,
#        2015, 2016, 2017], dtype=int64)

# %%
df['Year'].value_counts(dropna = False).sort_index()
# Out:
# 1970      651
# 1971      471
# 1972      568
# 1973      473
# 1974      581
# 1975      740
# 1976      923
# 1977     1319
# 1978     1526
# 1979     2662
# 1980     2662
# 1981     2586
# 1982     2544
# 1983     2870
# 1984     3495
# 1985     2915
# 1986     2860
# 1987     3183
# 1988     3721
# 1989     4324
# 1990     3887
# 1991     4683
# 1992     5071
# 1994     3456
# 1995     3081
# 1996     3058
# 1997     3197
# 1998      934
# 1999     1395
# 2000     1814
# 2001     1906
# 2002     1333
# 2003     1278
# 2004     1166
# 2005     2017
# 2006     2758
# 2007     3242
# 2008     4805
# 2009     4721
# 2010     4826
# 2011     5076
# 2012     8522
# 2013    12036
# 2014    16903
# 2015    14965
# 2016    13587
# 2017    10900
# Name: Year, dtype: int64

# %% [markdown]
# ### **Attack in Years**

# %%
year = df['Year'].unique()
years_count = df['Year'].value_counts(dropna = False).sort_index()
plt.figure(figsize = (20,10))
sns.barplot(x = year, y = years_count, palette = "tab10")
plt.xticks(rotation = 30)
plt.xlabel('Attacking Year',fontsize=20)
plt.ylabel('Number of Attacks Each Year',fontsize=20)
plt.title('Attacks In Years',fontsize=30)
plt.show()

# %% [markdown]
# **Highest Number of Attacking Year**
# * **2014**
#
# **Lowest Number of attacking Year**
# * **1971**

# %%
pd.crosstab(df.Year, df.Region).plot(kind='area',stacked=False,figsize=(20,10),cmap='viridis')
plt.title('Terrorist Activities By Region In Each Year',fontsize=25)
plt.ylabel('Number of Attacks',fontsize=20)
plt.xlabel("Year",fontsize=20)
plt.show()

# %%
attack=df.Country.value_counts().head(10)
attack
# Out:
# Iraq              24636
# Pakistan          14368
# Afghanistan       12731
# India             11960
# Colombia           8306
# Philippines        6908
# Peru               6096
# El Salvador        5320
# United Kingdom     5235
# Turkey             4292
# Name: Country, dtype: int64

# %%
plt.subplots(figsize=(20,8))
sns.barplot(df['Country'].value_counts()[:20].index, df['Country'].value_counts()[:20].values)
plt.title('Top Countries Affected')
plt.xlabel('Countries')
plt.ylabel('Count')
plt.xticks(rotation = 90)
plt.show()

# %%
df.Group.value_counts()[1:10]
# Out:
# Taliban                                             7478
# Islamic State of Iraq and the Levant (ISIL)         5613
# Shining Path (SL)                                   4555
# Farabundo Marti National Liberation Front (FMLN)    3351
# Al-Shabaab                                          3288
# New People's Army (NPA)                             2772
# Irish Republican Army (IRA)                         2671
# Revolutionary Armed Forces of Colombia (FARC)       2487
# Boko Haram                                          2418
# Name: Group, dtype: int64

# %%
df1=df.groupby(['Year'])[['kill']].sum()
df1.head(10)
# Out:
#         kill
# Year
# 1970   174.0
# 1971   173.0
# 1972   566.0
# 1973   370.0
# 1974   539.0
# 1975   617.0
# 1976   674.0
# 1977   456.0
# 1978  1459.0
# 1979  2100.0

# %%
fig, ax4 = plt.subplots(figsize=(20,8))
df1.plot(kind='bar',alpha=0.7,ax=ax4)
plt.xticks(rotation = 50)
plt.title("People Died Due To Attack",fontsize=25)
plt.ylabel("Number of killed peope",fontsize=20)
plt.xlabel('Year',fontsize=20)
# Out:
# Text(0.5, 0, 'Year')

# %%
df_city=df['City'].value_counts()
df_city[1:11]
# Out:
# Baghdad         7589
# Karachi         2652
# Lima            2359
# Mosul           2265
# Belfast         2171
# Santiago        1621
# Mogadishu       1581
# San Salvador    1558
# Istanbul        1048
# Athens          1019
# Name: City, dtype: int64

# %%
df['City'].value_counts()[1:11].plot(kind='bar',figsize=(20,10),color='blue',fontsize=12)
plt.xticks(rotation = 0)
plt.xlabel("City",fontsize=15)
plt.ylabel("Number of attack",fontsize=15)
plt.title("Top 10 most effected city",fontsize=20)
plt.show()

# %% [markdown]
# ### Number of Attacktype

# %%
df['Attacktype'].value_counts().plot(kind='bar',figsize=(20,10),color='magenta',fontsize=12)
plt.xticks(rotation = 50)
plt.xlabel("Attacktype",fontsize=15)
plt.ylabel("Number of attack",fontsize=15)
plt.title("Number of attacktype",fontsize=20)
plt.show()

# %% [markdown]
# **Most Number of Attack**
# * **Bombing/Explosion**

# %% [markdown]
# ### Number of Kill

# %%
df[['Attacktype','kill']].groupby(["Attacktype"]).sum().plot(kind='bar',figsize=(20,8),color='darkslateblue',fontsize=12)
plt.xticks(rotation=50)
plt.title("Number of killed ",fontsize=20)
plt.ylabel('Number of people',fontsize=15)
plt.xlabel('Attack type',fontsize=15)
plt.show()

# %% [markdown]
# **Most Number of Kill**
# * **Armed Assault**

# %% [markdown]
# ### Number of Wounded

# %%
df[['Attacktype','Wound']].groupby(["Attacktype"],axis=0).sum().plot(kind='bar',figsize=(20,8),color='cyan',fontsize=12)
plt.xticks(rotation=50)
plt.title("Number of wounded  ",fontsize=20)
plt.ylabel('Number of people',fontsize=15)
plt.xlabel('Attack type',fontsize=15)
plt.show()

# %% [markdown]
# **Most Number of Wounded**
# * **Bombing/Explosion**

# %% [markdown]
# ### Per Year Attack

# %%
plt.subplots(figsize=(20,10))
sns.countplot(df["Targettype"],order=df['Targettype'].value_counts().index,palette="gist_heat",edgecolor=sns.color_palette("mako"));
plt.xticks(rotation=90)
plt.xlabel("Attacktype",fontsize=15)
plt.ylabel("count",fontsize=15)
plt.title("Attack per year",fontsize=20)
plt.show()

# %% [markdown]
# ### Top 10 Terrorist Group Attack

# %%
df['Group'].value_counts().to_frame().drop('Unknown').head(10).plot(kind='bar',color='green',figsize=(20,8),fontsize=12)
plt.title("Top 10 terrorist group attack",fontsize=20)
plt.xlabel("terrorist group name",fontsize=15)
plt.ylabel("Attack number",fontsize=15)
plt.xticks(rotation=90)
plt.show()

# %%
df[['Group','kill']].groupby(['Group'],axis=0).sum().drop('Unknown').sort_values('kill',ascending=False).head(10).plot(kind='bar',color='yellow',figsize=(20,10),fontsize=12)
plt.title("Top 10 terrorist group attack",fontsize=20)
plt.xlabel("terrorist group name",fontsize=15)
plt.ylabel("No of killed people",fontsize=15)
plt.show()

# %% [markdown]
# ### Group, Country & Kill Wise Analysis

# %%
df_group=df[['Group','Country','kill']]
df_group=df.groupby(['Group','Country']).sum().sort_values('kill',ascending=False).drop('Unknown').reset_index().head(10)
df_group
# Out:
#                                               Group      Country      Year  \
# 0       Islamic State of Iraq and the Levant (ISIL)         Iraq   9667687
# 1                                           Taliban  Afghanistan  14943888
# 2                                        Boko Haram      Nigeria   4203203
# 3                                 Shining Path (SL)         Peru   9024885
# 4           Liberation Tigers of Tamil Eelam (LTTE)    Sri Lanka   3187199
# 5                                        Al-Shabaab      Somalia   5775226
# 6  Farabundo Marti National Liberation Front (FMLN)  El Salvador   6613775
# 7       Islamic State of Iraq and the Levant (ISIL)        Syria   1197127
# 8                 Nicaraguan Democratic Force (FDN)    Nicaragua   1758386
# 9                   Tehrik-i-Taliban Pakistan (TTP)     Pakistan   2686321
#
#    Month     day       latitude      longitude     kill    Wound
# 0  31408   76074  165025.991200  208864.405892  31058.0  23697.0
# ...

# %%
kill = df.loc[:,'kill']
print('Number of people killed by terror attack:', int(sum(kill.dropna())))
# Out:
# Number of people killed by terror attack: 411868

# %% [markdown]
# ### **Attacktype Wise Kill**

# %%
typeKill = df.pivot_table(columns='Attacktype', values='kill', aggfunc='sum')
typeKill
# Out:
# Attacktype  Armed Assault  Assassination  Bombing/Explosion  \
# kill             160297.0        24920.0           157321.0
#
# Attacktype  Facility/Infrastructure Attack  Hijacking  \
# kill                                3642.0     3718.0
#
# Attacktype  Hostage Taking (Barricade Incident)  Hostage Taking (Kidnapping)  \
# kill                                     4478.0                      24231.0
#
# Attacktype  Unarmed Assault  Unknown
# kill                  880.0  32381.0

# %%
typekill1=df.groupby(['Attacktype'])[['kill']].sum()
typekill1
# Out:
#                                          kill
# Attacktype
# Armed Assault                        160297.0
# Assassination                         24920.0
# Bombing/Explosion                    157321.0
# Facility/Infrastructure Attack         3642.0
# Hijacking                              3718.0
# Hostage Taking (Barricade Incident)    4478.0
# Hostage Taking (Kidnapping)           24231.0
# Unarmed Assault                         880.0
# Unknown                               32381.0

# %% [markdown]
# **Most Attacktype in Kill**
# * **Armed Assault**

# %% [markdown]
# ### **Country Wise Kill**

# %%
countryKill = df.pivot_table(columns='Country', values='kill', aggfunc='sum')
countryKill
# Out:
# Country  Afghanistan  Albania  Algeria  Andorra  Angola  Antigua and Barbuda  \
# kill         39384.0     42.0  11066.0      0.0  3043.0                  0.0
#
# Country  Argentina  Armenia  Australia  Austria  ...  Vietnam  \
# kill         490.0     37.0       23.0     30.0  ...      1.0
#
# Country  Wallis and Futuna  West Bank and Gaza Strip  West Germany (FRG)  \
# kill                   0.0                    1500.0                97.0
#
# Country  Western Sahara   Yemen  Yugoslavia  Zaire  Zambia  Zimbabwe
# kill                1.0  8776.0       119.0  324.0    70.0     154.0
#
# [1 rows x 205 columns]

# %%
countrykill1=df.groupby(['Country'])[['kill']].sum().sort_values('kill')
countrykill1
# Out:
#                      kill
# Country
# French Polynesia      0.0
# Benin                 0.0
# Seychelles            0.0
# New Hebrides          0.0
# South Yemen           0.0
# ...                   ...
# India             19341.0
# Nigeria           22682.0
# Pakistan          23822.0
# Afghanistan       39384.0
# Iraq              78589.0
#
# [205 rows x 1 columns]

# %% [markdown]
# **Most Country in Kill**
# * **Iraq**

# %% [markdown]
# # Thank You
